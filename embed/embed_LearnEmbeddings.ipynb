# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

import requests
import re
import string

from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.nn.functional as F

from torchinfo import summary

import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
# Checking if Python evt can see Apple GPU (using MPS Metal Performance Shaders - Metal API)
print("PyTorch version:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())
# Out:
# PyTorch version: 2.8.0
# MPS available: True
# MPS built: True

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: mps

# %%
x = torch.randn(1000, 1000, device=device)
y = torch.randn(1000, 1000, device=device)
z = x @ y
print(z.device)
# Out:
# mps:0

# %%
a=torch.tensor(10)
print(a)
print(a.device)
# Out:
# tensor(10)
# cpu

# %% [markdown]
# ## Import text and create dict

# %%
# get raw text fro, internet (Time Machine)

text = requests.get('https://www.gutenberg.org/files/35/35-0.txt').text
# chara string to replace with space
strings2replace = [ '\r\n\r\n\â\x90\x9c', 'â\x80\x9c', 'â\x80\x9d', '\r\n','â\x80\x94']
# use reg exp to replace those stings with space
for str2match in strings2replace:
    text = re.compile(r'%s'%str2match).sub(' ',text)

#remove non ascii char and numbers and make lower case
text = re.sub(r'[^\x00-\x7F]+',' ',text)
text = re.sub('\d+', '',text).lower()

#split into words with >1 letter
words = re.split(f'[{string.punctuation}\s]+',text)
words = [item.strip() for item in words if item.strip()]
words = [item for item in words if len(item)>1]

# create vocab 
vocab = sorted(set(words))
nWords = len(words)
nVocab = len(vocab)

# encode/decoder look up tables 
word2idx = {w:i for i,w in enumerate(vocab)}
idx2word = {i:w for i,w in enumerate(vocab)}

print(f'The book contains {nWords} words, {nVocab} of which are unique')
print(f'\n\nFirst 10 vocab words:\n',list(word2idx.keys())[:10])
# Out:
# The book contains 30698 words, 4589 of which are unique
#
#
# First 10 vocab words:
#  ['abandon', 'abandoned', 'able', 'abnormally', 'abominable', 'abominations', 'about', 'above', 'abruptly', 'absence']

# %%
text
# Out:
# '*** start of the project gutenberg ebook  ***     the time machine  an invention  by h. g. wells   contents   i introduction  ii the machine  iii the time traveller returns  iv time travelling  v in the golden age  vi the sunset of mankind  vii a sudden shock  viii explanation  ix the morlocks  x when night came  xi the palace of green porcelain  xii in the darkness  xiii the trap of the white sphinx  xiv the further vision  xv the time traveller s return  xvi after the story  epilogue      i.  introduction   the time traveller (for so it will be convenient to speak of him) was expounding a recondite matter to us. his pale grey eyes shone and twinkled, and his usually pale face was flushed and animated. the fire burnt brightly, and the soft radiance of the incandescent lights in the lilies of silver caught the bubbles that flashed and passed in our glasses. our chairs, being his patents, embraced and caressed us rather than submitted to be sat upon, and there was that luxurious after-dinner atmosphere, when thought runs gracefully free of the trammels of precision. and he put it to us in this way marking the points with a lean forefinger as we sat and lazily admired his earnestness over this new paradox (as we thought it) and his fecundity.   you must follow me carefully. i shall have to controvert one or two ideas that are almost universally accepted. the geometry, for instance, they taught you at school is founded on a misconception.    is not that rather a large thing to expect us to begin upon?  said filby, an argumentative person with red hair.   i do not mean to ask you to accept anything without reasonable ground for it. you will soon admit as much as i need from you. you know of course that a mathematical line, a line of thickness _nil_, has no real existence. they taught you that? neither has a mathematical plane. these things are mere abstractions.    that is all right,  said the psychologist.   nor, having only length, breadth, and thickness, can a cube have a real existence.    there i object,  said filby.  of course a solid body may exist. all real things    so most people think. but wait a moment. can an _instantaneous_ cube exist?    don t follow you,  said filby.   can a cube that does not last for any time at all, have a real existence?   filby became pensive.  clearly,  the time traveller proceeded,  any real body must have extension in _four_ directions: it must have length, breadth, thickness, and duration. but through a natural infirmity of the flesh, which i will explain to you in a moment, we incline to overlook this fact. there are really four dimensions, three which we call the three planes of space, and a fourth, time. there is, however, a tendency to draw an unreal distinction between the former three dimensions and the latter, because it happens that our consciousness moves intermittently in one direction along the latter from the beginning to the end of our lives.    that,  said a very young man, making spasmodic efforts to relight his cigar over the lamp;  that . . . very clear indeed.    now, it is very remarkable that this is so extensively overlooked,  continued the time traveller, with a slight accession of cheerfulness.  really this is what is meant by the fourth dimension, though some people who talk about the fourth dimension do not know they mean it. it is only another way of looking at time. _there is no difference between time and any of the three dimensions of space except that our consciousness moves along it_. but some foolish people have got hold of the wrong side of that idea. you have all heard what they have to say about this fourth dimension?    _i_ have not,  said the provincial mayor.   it is simply this. that space, as our mathematicians have it, is spoken of as having three dimensions, which one may call length, breadth, and thickness, and is always definable by reference to three planes, each at right angles to the others. but some philosophical people have been asking why  ...

# %%
words
# Out:
# ['start',
#  'of',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'the',
#  'time',
#  'machine',
#  'an',
#  'invention',
#  'by',
#  'wells',
#  'contents',
#  'introduction',
#  'ii',
#  'the',
#  'machine',
#  'iii',
#  'the',
#  'time',
#  'traveller',
#  'returns',
#  'iv',
#  'time',
#  'travelling',
#  'in',
#  'the',
#  'golden',
#  'age',
#  'vi',
#  'the',
#  'sunset',
#  'of',
#  'mankind',
#  'vii',
#  'sudden',
#  'shock',
#  'viii',
#  'explanation',
#  'ix',
#  'the',
#  'morlocks',
#  'when',
#  'night',
#  'came',
#  'xi',
#  'the',
#  'palace',
#  'of',
#  'green',
#  'porcelain',
#  'xii',
#  'in',
#  'the',
#  'darkness',
#  'xiii',
#  'the',
#  'trap',
#  'of',
#  'the',
#  'white',
#  'sphinx',
#  'xiv',
#  'the',
#  'further',
#  'vision',
#  'xv',
#  'the',
#  'time',
#  'traveller',
#  'return',
#  'xvi',
#  'after',
#  'the',
#  'story',
#  'epilogue',
#  'introduction',
#  'the',
#  'time',
#  'traveller',
#  'for',
#  'so',
#  'it',
#  'will',
#  'be',
#  'convenient',
#  'to',
#  'speak',
#  'of',
#  'him',
#  'was',
#  'expounding',
#  'recondite',
#  'matter',
#  'to',
#  'us',
#  'his',
#  'pale',
#  'grey',
#  'eyes',
#  'shone',
#  'and',
#  'twinkled',
#  'and',
#  'his',
#  'usually',
#  'pale',
#  'face',
#  'was',
#  'flushed',
#  'and',
#  'animated',
#  'the',
#  'fire',
#  'burnt',
#  'brightly',
#  'and',
#  'the',
#  'soft',
#  'radiance',
#  'of',
#  'the',
#  'incandescent',
#  'lights',
#  'in',
#  'the',
#  'lilies',
#  'of',
#  'silver',
#  'caught',
#  'the',
#  'bubbles',
#  'that',
#  'flashed',
#  'and',
#  'passed',
#  'in',
#  'our',
#  'glasses',
#  'our',
#  'chairs',
#  'being',
#  'his',
#  'patents',
#  'embraced',
#  'and',
#  'caressed',
#  'us',
#  'rather',
#  'than',
#  'submitted',
#  'to',
#  'be',
#  'sat',
#  'upon',
#  'and',
#  'there',
#  'was',
#  'that',
#  'luxurious',
#  'after',
#  'dinner',
#  'atmosphere',
#  'when',
#  'thought',
#  'runs',
#  'gracefully',
#  'free',
#  'of',
#  'the',
#  'trammels',
#  'of',
#  'precision',
#  'and',
#  'he',
#  'put',
#  'it',
#  'to',
#  'us',
#  'in',
#  'this',
#  'way',
#  'marking',
#  'the',
#  'points',
#  'with',
#  'lean',
#  'forefinger',
#  'as',
#  'we',
#  'sat',
#  'and',
#  'lazily',
#  'admired',
#  'his',
#  'earnestness',
#  'over',
#  'this',
#  'new',
#  'paradox',
#  'as',
#  'we',
#  'thought',
#  'it',
#  'and',
#  'his',
#  'fecundity',
#  'you',
#  'must',
#  'follow',
#  'me',
#  'carefully',
#  'shall',
#  'have',
#  'to',
#  'controvert',
#  'one',
#  'or',
#  'two',
#  'ideas',
#  'that',
#  'are',
#  'almost',
#  'universally',
#  'accepted',
#  'the',
#  'geometry',
#  'for',
#  'instance',
#  'they',
#  'taught',
#  'you',
#  'at',
#  'school',
#  'is',
#  'founded',
#  'on',
#  'misconception',
#  'is',
#  'not',
#  'that',
#  'rather',
#  'large',
#  'thing',
#  'to',
#  'expect',
#  'us',
#  'to',
#  'begin',
#  'upon',
#  'said',
#  'filby',
#  'an',
#  'argumentative',
#  'person',
#  'with',
#  'red',
#  'hair',
#  'do',
#  'not',
#  'mean',
#  'to',
#  'ask',
#  'you',
#  'to',
#  'accept',
#  'anything',
#  'without',
#  'reasonable',
#  'ground',
#  'for',
#  'it',
#  'you',
#  'will',
#  'soon',
#  'admit',
#  'as',
#  'much',
#  'as',
#  'need',
#  'from',
#  'you',
#  'you',
#  'know',
#  'of',
#  'course',
#  'that',
#  'mathematical',
#  'line',
#  'line',
#  'of',
#  'thickness',
#  'nil',
#  'has',
#  'no',
#  'real',
#  'existence',
#  'they',
#  'taught',
#  'you',
#  'that',
#  'neither',
#  'has',
#  'mathematical',
#  'plane',
#  'these',
#  'things',
#  'are',
#  'mere',
#  'abstractions',
#  'that',
#  'is',
#  'all',
#  'right',
#  'said',
#  'the',
#  'psychologist',
#  'nor',
#  'having',
#  'only',
#  'length',
#  'breadth',
#  'and',
#  'thickness',
#  'can',
#  'cube',
#  'have',
#  'real',
#  'existence',
#  'there',
#  'object',
#  'said',
#  'filby',
#  'of',
#  'course',
#  'solid',
#  'body',
#  'may',
#  'exist',
#  'all',
#  'real',
#  'things',
#  'so',
#  'most',
#  'people',
#  'think',
#  'but',
#  'wait',
#  'moment',
#  'can',
#  'an',
#  'instantaneous',
#  'cube',
#  'exist',
#  'don',
#  'follow',
#  'you',
#  'said',
#  'filby',
#  'can',
#  'cube',
#  'that',
#  'does',
#  'not',
#  'last',
#  'for',
#  'any',
#  'time',
#  'at',
#  'all',
#  'have',
#  'real',
#  'existence',
#  'filby',
#  'became',
#  'pensive',
#  'clearly',
#  'the',
#  'time',
#  'traveller',
#  'proceeded',
#  'any',
#  'real',
#  'body',
#  'must',
#  'have',
#  'extension',
#  'in',
#  'four',
#  'directions',
#  'it',
#  'must',
#  'have',
#  'length',
#  'breadth',
#  'thickness',
#  'and',
#  'duration',
#  'but',
#  'through',
#  'natural',
#  'infirmity',
#  'of',
#  'the',
#  'flesh',
#  'which',
#  'will',
#  'explain',
#  'to',
#  'you',
#  'in',
#  'moment',
#  'we',
#  'incline',
#  'to',
#  'overlook',
#  'this',
#  'fact',
#  'there',
#  'are',
#  'really',
#  'four',
#  'dimensions',
#  'three',
#  'which',
#  'we',
#  'call',
#  'the',
#  'three',
#  'planes',
#  'of',
#  'space',
#  'and',
#  'fourth',
#  'time',
#  'there',
#  'is',
#  'however',
#  'tendency',
#  'to',
#  'draw',
#  'an',
#  'unreal',
#  'distinction',
#  'between',
#  'the',
#  'former',
#  'three',
#  'dimensions',
#  'and',
#  'the',
#  'latter',
#  'because',
#  'it',
#  'happens',
#  'that',
#  'our',
#  'consciousness',
#  'moves',
#  'intermittently',
#  'in',
#  'one',
#  'direction',
#  'along',
#  'the',
#  'latter',
#  'from',
#  'the',
#  'beginning',
#  'to',
#  'the',
#  'end',
#  'of',
#  'our',
#  'lives',
#  'that',
#  'said',
#  'very',
#  'young',
#  'man',
#  'making',
#  'spasmodic',
#  'efforts',
#  'to',
#  'relight',
#  'his',
#  'cigar',
#  'over',
#  'the',
#  'lamp',
#  'that',
#  'very',
#  'clear',
#  'indeed',
#  'now',
#  'it',
#  'is',
#  'very',
#  'remarkable',
#  'that',
#  'this',
#  'is',
#  'so',
#  'extensively',
#  'overlooked',
#  'continued',
#  'the',
#  'time',
#  'traveller',
#  'with',
#  'slight',
#  'accession',
#  'of',
#  'cheerfulness',
#  'really',
#  'this',
#  'is',
#  'what',
#  'is',
#  'meant',
#  'by',
#  'the',
#  'fourth',
#  'dimension',
#  'though',
#  'some',
#  'people',
#  'who',
#  'talk',
#  'about',
#  'the',
#  'fourth',
#  'dimension',
#  'do',
#  'not',
#  'know',
#  'they',
#  'mean',
#  'it',
#  'it',
#  'is',
#  'only',
#  'another',
#  'way',
#  'of',
#  'looking',
#  'at',
#  'time',
#  'there',
#  'is',
#  'no',
#  'difference',
#  'between',
#  'time',
#  'and',
#  'any',
#  'of',
#  'the',
#  'three',
#  'dimensions',
#  'of',
#  'space',
#  'except',
#  'that',
#  'our',
#  'consciousness',
#  'moves',
#  'along',
#  'it',
#  'but',
#  'some',
#  'foolish',
#  'people',
#  'have',
#  'got',
#  'hold',
#  'of',
#  'the',
#  'wrong',
#  'side',
#  'of',
#  'that',
#  'idea',
#  'you',
#  'have',
#  'all',
#  'heard',
#  'what',
#  'they',
#  'have',
#  'to',
#  'say',
#  'about',
#  'this',
#  'fourth',
#  'dimension',
#  'have',
#  'not',
#  'said',
#  'the',
#  'provincial',
#  'mayor',
#  'it',
#  'is',
#  'simply',
#  'this',
#  'that',
#  'space',
#  'as',
#  'our',
#  'mathematicians',
#  'have',
#  'it',
#  'is',
#  'spoken',
#  'of',
#  'as',
#  'having',
#  'three',
#  'dimensions',
#  'which',
#  'one',
#  'may',
#  'call',
#  'length',
#  'breadth',
#  'and',
#  'thickness',
#  'and',
#  'is',
#  'always',
#  'definable',
#  'by',
#  'reference',
#  'to',
#  'three',
#  'planes',
#  'each',
#  'at',
#  'right',
#  'angles',
#  'to',
#  'the',
#  'others',
#  'but',
#  'some',
#  'philosophical',
#  'people',
#  'have',
#  'been',
#  'asking',
#  'why',
#  'three',
#  'dimensions',
#  'particularly',
#  'why',
#  'not',
#  'another',
#  'direction',
#  'at',
#  'right',
#  'angles',
#  'to',
#  'the',
#  'other',
#  'three',
#  'and',
#  'have',
#  'even',
#  'tried',
#  'to',
#  'construct',
#  'four',
#  'dimensional',
#  'geometry',
#  'professor',
#  'simon',
#  'newcomb',
#  'was',
#  'expounding',
#  'this',
#  'to',
#  'the',
#  'new',
#  'york',
#  'mathematical',
#  'society',
#  'only',
#  'month',
#  'or',
#  'so',
#  'ago',
#  'you',
#  'know',
#  'how',
#  'on',
#  'flat',
#  'surface',
#  'which',
#  'has',
#  'only',
#  'two',
#  'dimensions',
#  'we',
#  'can',
#  'represent',
#  'figure',
#  'of',
#  'three',
#  'dimensional',
#  'solid',
#  'and',
#  'similarly',
#  'they',
#  'think',
#  'that',
#  'by',
#  'models',
#  'of',
#  'three',
#  'dimensions',
#  'they',
#  'could',
#  'represent',
#  'one',
#  'of',
#  'four',
#  'if',
#  'they',
#  'could',
#  'master',
#  'the',
#  'perspective',
#  'of',
#  'the',
#  'thing',
#  'see',
#  'think',
#  'so',
#  'murmured',
#  'the',
#  'provincial',
#  'mayor',
#  'and',
#  'knitting',
#  'his',
#  'brows',
#  'he',
#  'lapsed',
#  'into',
#  'an',
#  'introspective',
#  'state',
#  'his',
#  'lips',
#  'moving',
#  'as',
#  'one',
#  'who',
#  'repeats',
#  'mystic',
#  'words',
#  'yes',
#  'think',
#  'see',
#  'it',
#  'now',
#  'he',
#  'said',
#  'after',
#  'some',
#  'time',
#  'brightening',
#  'in',
#  'quite',
#  'transitory',
#  'manner',
#  'well',
#  'do',
#  'not',
#  'mind',
#  'telling',
#  'you',
#  'have',
#  'been',
#  'at',
#  'work',
#  'upon',
#  'this',
#  'geometry',
#  'of',
#  'four',
#  'dimensions',
#  'for',
#  'some',
#  'time',
#  'some',
#  'of',
#  'my',
#  'results',
#  'are',
#  'curious',
#  'for',
#  'instance',
#  'here',
#  'is',
#  'portrait',
#  'of',
#  'man',
#  'at',
#  'eight',
#  'years',
#  'old',
#  'another',
#  'at',
#  'fifteen',
#  'another',
#  'at',
#  'seventeen',
#  'another',
#  'at',
#  'twenty',
#  'three',
#  'and',
#  'so',
#  'on',
#  'all',
#  'these',
#  'are',
#  'evidently',
#  'sections',
#  'as',
#  'it',
#  'were',
#  'three',
#  'dimensional',
#  'representations',
#  'of',
#  'his',
#  'four',
#  'dimensioned',
#  'being',
#  'which',
#  'is',
#  'fixed',
#  'and',
#  'unalterable',
#  'thing',
#  'scientific',
#  'people',
#  'proceeded',
#  'the',
#  'time',
#  'traveller',
#  'after',
#  'the',
#  'pause',
#  'required',
#  'for',
#  'the',
#  'proper',
#  'assimilation',
#  'of',
#  'this',
#  'know',
#  'very',
#  'well',
#  'that',
#  'time',
#  'is',
#  'only',
#  'kind',
#  'of',
#  'space',
#  'here',
#  'is',
#  'popular',
#  'scientific',
#  'diagram',
#  'weather',
#  'record',
#  'this',
#  'line',
#  'trace',
#  'with',
#  'my',
#  'finger',
#  'shows',
#  'the',
#  'movement',
#  'of',
#  'the',
#  'barometer',
#  'yesterday',
#  'it',
#  'was',
#  'so',
#  'high',
#  'yesterday',
#  'night',
#  'it',
#  'fell',
#  'then',
#  'this',
#  'morning',
#  'it',
#  'rose',
#  'again',
#  'and',
#  'so',
#  'gently',
#  'upward',
#  'to',
#  'here',
#  'surely',
#  'the',
#  'mercury',
#  'did',
#  'not',
#  'trace',
#  'this',
#  'line',
#  'in',
#  'any',
#  'of',
#  'the',
#  'dimensions',
#  'of',
#  'space',
#  'generally',
#  'recognised',
#  'but',
#  'certainly',
#  'it',
#  'traced',
#  'such',
#  'line',
#  'and',
#  'that',
#  'line',
#  'therefore',
#  'we',
#  'must',
#  'conclude',
#  'was',
#  'along',
#  'the',
#  'time',
#  'dimension',
#  'but',
#  'said',
#  'the',
#  'medical',
#  'man',
#  'staring',
#  'hard',
#  'at',
#  'coal',
#  'in',
#  'the',
#  'fire',
#  'if',
#  'time',
#  'is',
#  'really',
#  'only',
#  'fourth',
#  'dimension',
#  'of',
#  'space',
#  'why',
#  'is',
#  'it',
#  'and',
#  'why',
#  'has',
#  'it',
#  'always',
#  'been',
#  'regarded',
#  'as',
#  'something',
#  'different',
#  'and',
#  'why',
#  'cannot',
#  'we',
#  'move',
#  'in',
#  'time',
#  'as',
#  'we',
#  'move',
#  'about',
#  'in',
#  'the',
#  'other',
#  'dimensions',
#  'of',
#  ...]

# %% [markdown]
# ## Define the para of dataset

# %%
# parameters of dataset
context_length = 8 # context length(seq lenght)
stride = 2

#initalize
inputs = []
targets = []

#overlapping seq of context_length
for i in range(0,nWords-context_length, stride):
    # get a few words
    in_seq = words[i:i+context_length]
    targ_seq = words[i+1:i+context_length+1]

    #append to lists
    inputs.append([word2idx[w] for w in in_seq])
    targets.append([word2idx[w] for w in targ_seq])
len(inputs)
# Out:
# 15345

# %%
print(inputs[123])
print(targets[123])
# Out:
# [1342, 4304, 4119, 342, 4296, 3388, 1474, 131]
# [4304, 4119, 342, 4296, 3388, 1474, 131, 209]

# %%
print(inputs[124])
print(targets[124])
# Out:
# [4119, 342, 4296, 3388, 1474, 131, 209, 2907]
# [342, 4296, 3388, 1474, 131, 209, 2907, 4510]

# %%
# we need the above in a different format in torch Dataset/DataLoader format

# We need each list to be a tensor
torch.tensor(inputs[123])
# Out:
# tensor([1342, 4304, 4119,  342, 4296, 3388, 1474,  131])

# %%
len(text)
# Out:
# 179773

# %% [markdown]
# ## Create a class for a dataset object

# %%
print(len(words))
print('\n\n', words)
# Out:
# 30698
#
#
#  ['start', 'of', 'the', 'project', 'gutenberg', 'ebook', 'the', 'time', 'machine', 'an', 'invention', 'by', 'wells', 'contents', 'introduction', 'ii', 'the', 'machine', 'iii', 'the', 'time', 'traveller', 'returns', 'iv', 'time', 'travelling', 'in', 'the', 'golden', 'age', 'vi', 'the', 'sunset', 'of', 'mankind', 'vii', 'sudden', 'shock', 'viii', 'explanation', 'ix', 'the', 'morlocks', 'when', 'night', 'came', 'xi', 'the', 'palace', 'of', 'green', 'porcelain', 'xii', 'in', 'the', 'darkness', 'xiii', 'the', 'trap', 'of', 'the', 'white', 'sphinx', 'xiv', 'the', 'further', 'vision', 'xv', 'the', 'time', 'traveller', 'return', 'xvi', 'after', 'the', 'story', 'epilogue', 'introduction', 'the', 'time', 'traveller', 'for', 'so', 'it', 'will', 'be', 'convenient', 'to', 'speak', 'of', 'him', 'was', 'expounding', 'recondite', 'matter', 'to', 'us', 'his', 'pale', 'grey', 'eyes', 'shone', 'and', 'twinkled', 'and', 'his', 'usually', 'pale', 'face', 'was', 'flushed', 'and', 'animated', 'the', 'fire', 'burnt', 'brightly', 'and', 'the', 'soft', 'radiance', 'of', 'the', 'incandescent', 'lights', 'in', 'the', 'lilies', 'of', 'silver', 'caught', 'the', 'bubbles', 'that', 'flashed', 'and', 'passed', 'in', 'our', 'glasses', 'our', 'chairs', 'being', 'his', 'patents', 'embraced', 'and', 'caressed', 'us', 'rather', 'than', 'submitted', 'to', 'be', 'sat', 'upon', 'and', 'there', 'was', 'that', 'luxurious', 'after', 'dinner', 'atmosphere', 'when', 'thought', 'runs', 'gracefully', 'free', 'of', 'the', 'trammels', 'of', 'precision', 'and', 'he', 'put', 'it', 'to', 'us', 'in', 'this', 'way', 'marking', 'the', 'points', 'with', 'lean', 'forefinger', 'as', 'we', 'sat', 'and', 'lazily', 'admired', 'his', 'earnestness', 'over', 'this', 'new', 'paradox', 'as', 'we', 'thought', 'it', 'and', 'his', 'fecundity', 'you', 'must', 'follow', 'me', 'carefully', 'shall', 'have', 'to', 'controvert', 'one', 'or', 'two', 'ideas', 'that', 'are', 'almost', 'universally', 'accepted', 'the', 'geometry', 'for', 'instance', 'they', 'taught', 'you', 'at', 'school', 'is', 'founded', 'on', 'misconception', 'is', 'not', 'that', 'rather', 'large', 'thing', 'to', 'expect', 'us', 'to', 'begin', 'upon', 'said', 'filby', 'an', 'argumentative', 'person', 'with', 'red', 'hair', 'do', 'not', 'mean', 'to', 'ask', 'you', 'to', 'accept', 'anything', 'without', 'reasonable', 'ground', 'for', 'it', 'you', 'will', 'soon', 'admit', 'as', 'much', 'as', 'need', 'from', 'you', 'you', 'know', 'of', 'course', 'that', 'mathematical', 'line', 'line', 'of', 'thickness', 'nil', 'has', 'no', 'real', 'existence', 'they', 'taught', 'you', 'that', 'neither', 'has', 'mathematical', 'plane', 'these', 'things', 'are', 'mere', 'abstractions', 'that', 'is', 'all', 'right', 'said', 'the', 'psychologist', 'nor', 'having', 'only', 'length', 'breadth', 'and', 'thickness', 'can', 'cube', 'have', 'real', 'existence', 'there', 'object', 'said', 'filby', 'of', 'course', 'solid', 'body', 'may', 'exist', 'all', 'real', 'things', 'so', 'most', 'people', 'think', 'but', 'wait', 'moment', 'can', 'an', 'instantaneous', 'cube', 'exist', 'don', 'follow', 'you', 'said', 'filby', 'can', 'cube', 'that', 'does', 'not', 'last', 'for', 'any', 'time', 'at', 'all', 'have', 'real', 'existence', 'filby', 'became', 'pensive', 'clearly', 'the', 'time', 'traveller', 'proceeded', 'any', 'real', 'body', 'must', 'have', 'extension', 'in', 'four', 'directions', 'it', 'must', 'have', 'length', 'breadth', 'thickness', 'and', 'duration', 'but', 'through', 'natural', 'infirmity', 'of', 'the', 'flesh', 'which', 'will', 'explain', 'to', 'you', 'in', 'moment', 'we', 'incline', 'to', 'overlook', 'this', 'fact', 'there', 'are', 'really', 'four', 'dimensions', 'three', 'which', 'we', 'call', 'the', 'three', 'planes', 'of', 'space', 'and', 'fourth', 'time', 'there', 'is', 'however', 'tendency', 'to', 'draw', 'an', 'unreal', 'distinction', 'between', 'the', 'former', 'three', 'dimensions', 'and', 'the', 'latter', 'because', 'it', 'happens', 'that', 'our', 'con ...

# %%
class WordDataset(Dataset):
    def __init__(self, text, word2idx, context_length=8, stride=4):

        # init
        self.inputs = []
        self.targets = []
        self.word2idx = word2idx #stored locally in the object

        # overlapping seq of context_length
        for i in range(0,len(text)-context_length,stride):
            #get a few words
            in_seq = text[i:i+context_length]
            targ_seq = text[i+1:i+context_length+1]

            # append to lists
            self.inputs.append(torch.tensor([word2idx[w] for w in in_seq]))
            self.targets.append(torch.tensor([word2idx[w] for w in targ_seq]))

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self,idx):
        return self.inputs[idx], self.targets[idx]


# ceate an instance
context_length = 6
stride = 3
text_dataset = WordDataset(words, word2idx, context_length, stride)

print(text_dataset[4])
print('\n\n', text_dataset[5])
# Out:
# (tensor([4451,  783, 2167, 2005, 4042, 2416]), tensor([ 783, 2167, 2005, 4042, 2416, 2006]))
#
#
#  (tensor([2005, 4042, 2416, 2006, 4042, 4109]), tensor([4042, 2416, 2006, 4042, 4109, 4171]))

# %%
a,b = text_dataset[0]
print(a)
print(b)
# Out:
# tensor([3804, 2731, 4042, 3067, 1808, 1205])
# tensor([2731, 4042, 3067, 1808, 1205, 4042])

# %%
# Create a DataLoader for training
dataloader = DataLoader(text_dataset, 
                        batch_size = 32, # 2 for looking: 32 for training 
                        shuffle = True,
                        drop_last = True
                       )

# have a look at the indices
X,y = next(iter(dataloader))
print('Inputs:')
print(X), print('')

print('Targets:')
print(y), print('\n\n\n')

# and the words
print('Inputs in words (First batch):')
print([idx2word[item.item()] for item in X[0]])
print('')

print('Targets in words (First batch):')
print([idx2word[item.item()] for item in y[0]])

# and the words
print('\n\n\nInputs in words (Second batch):')
print([idx2word[item.item()] for item in X[1]])
print('')

print('Targets in words (Second batch):')
print([idx2word[item.item()] for item in y[1]])
# Out:
# Inputs:
# tensor([[ 484, 2731, 3838, 4042,  374, 1826],
#         [4453, 4119, 4042, 4120, 2194, 2740],
#         [1851, 2651, 3307, 1281, 2742,  528],
#         [ 408, 1156, 1823, 3403, 2731, 4042],
#         [3198, 4408, 3501, 2764, 1230, 2512],
#         [2593, 4119, 2228, 2571, 2764, 3693],
#         [2740,  519, 1406, 2041, 4042, 1198],
#         [1901, 1385, 4106, 3035, 1901, 1388],
#         [4109, 2679, 2731, 4304, 3138,  358],
#         [1861, 1742, 2163, 4042, 2861, 2003],
#         [3865, 2731, 2435,  137, 4042, 3700],
#         [ 137,  937,  137, 4042, 2128, 2731],
#         [3229, 2186,  230, 3332, 3102, 2731],
#         [4454,  340, 2382, 1572, 2651, 2499],
#         [4042, 3092, 4428, 4454,   96, 2740],
#         [2731, 1929, 1388,  137,   96, 2731],
#         [2186,   96, 4042, 3392, 4408, 2041],
#         [4042, 4297,  430, 2287,  367, 2186],
#         [2669, 2384,  418, 2682, 1198, 2186],
#         [ 387,  137, 1574, 4428, 1599, 3712],
#         [   6, 2508,  371, 4042, 2880, 2731],
#         [4482, 4544, 1851, 1742, 4560, 4428],
#         [4042, 3703, 4058, 4454,  713, 2739],
#         [ 230, 4119, 4042,  824, 3554, 3109],
#         [3321, 3699, 3347, 4058, 1815, 3468],
#         [4408,  255, 2741, 3914, 3975, 2783],
#         [2731, 1075, 3840, 2388,  255, 2186],
#         [4042, 3599,  378,   75, 2186, 4051],
#         [ 137,  822, 2731, 3736, 4454, 1950],
#         [4509,  817, 2171, 2186, 2183, 1971],
#         [4065, 2744, 2608, 1080, 4119, 2305],
#         [3554, 1861, 2890, 1929, 2580, 2989]])
#
# Targets:
# tensor([[2731, 3838, 4042,  374, 1826, 4408],
#         [4119, 4042, 4120, 2194, 2740, 4042],
#         [2651, 3307, 1281, 2742,  528,  630],
#         [1156, 1823, 3403, 2731, 4042,   77],
#         [4408, 3501, 2764, 1230, 2512,  501],
#         [4119, 2228, 2571, 2764, 3693, 4352],
#         [ 519, 1406, 2041, 4042, 1198, 3628],
#         [1385, 4106, 3035, 1901, 1388,   75],
#         [2679, 2731, 4304, 3138,  358, 2041],
#         [1742, 2163, 4042, 2861, 2003, 2186],
#         [2731, 2435,  137, 4042, 3700, 2731],
#         [ 937,  137, 4042, 2128, 2731, 4042],
#         [2186,  230, 3332, 3102, 2731, 1977],
#         [ 340, 2382, 1572, 2651, 2499, 2887],
#         [3092, 4428, 4454,   96, 2740, 4042],
#         [1929, 1388,  137,   96, 2731, 3915],
#         [  96, 4042, 3392, 4408, 2041, 2608],
#         [4297,  430, 2287,  367, 2186, 2041],
#         [2384,  418, 2682, 1198, 2186, 4408],
#         [ 137, 1574, 4428, 1599, 3712, 1643],
#         [2508,  371, 4042, 2880, 2731, 4042],
#         [4544, 1851, 1742, 4560, 4428,  204],
#         [3703, 4058, 4454,  713, 2739, 3547],
#         [4119, 4042,  824, 3554, 3109, 2608],
#         [3699, 3347, 4058, 1815, 3468, 2470],
#         [ 255, 2741, 3914, 3975, 2783, 2731],
#         [1075, 3840, 2388,  255, 2186, 1572],
#         [3599,  378,   75, 2186, 4051, 4408],
#         [ 822, 2731, 3736, 4454, 1950, 3363],
#         [ 817, 2171, 2186, 2183, 1971, 4042],
#         [2744, 2608, 1080, 4119, 2305, 4445],
#         [1861, 2890, 1929, 2580, 2989,  502]])
#
#
#
#
# Inputs in words (First batch):
# ['building', 'of', 'stone', 'the', 'big', 'hall']
#
# Targets in words (First batch):
# ['of', 'stone', 'the', 'big', 'hall', 'was']
#
#
#
# Inputs in words (Second batch):
# ['went', 'to', 'the', 'tobacco', 'jar', 'on']
#
# Targets in words (Second batch):
# ['to', 'the', 'tobacco', 'jar', 'on', 'the']

# %%
type(X)
# Out:
# torch.Tensor

# %% [markdown]
# ## Build a model to learn the embeddings

# %%
# create and explore an embedding layer

embeddingDimension = 100

#create a random embedding
embedding_layer = nn.Embedding(nVocab, embeddingDimension)

#see its size
embedding_layer.weight.shape
# Out:
# torch.Size([4589, 100])

# %%
# the embedding_layer is initialised randomly
# Every time a token passes through the model:

#    1.The embedding for that token is selected from the table.

#    2.The model predicts something.

#    3.Loss is computed.

#    4.Gradients update only the rows corresponding to the tokens used.

# %%
embedding_layer.weight
# Out:
# Parameter containing:
# tensor([[-1.7829, -1.1511, -0.1401,  ..., -0.1442, -0.5721,  0.5084],
#         [-0.7763, -0.1894,  0.9065,  ..., -0.0177, -1.4600,  0.1454],
#         [ 0.1425,  0.2960,  1.0012,  ...,  0.9729, -0.6686, -0.5687],
#         ...,
#         [ 0.6505, -1.3970,  0.8772,  ..., -0.9647, -1.1060,  0.6693],
#         [ 0.5472,  0.4466,  1.3605,  ..., -0.2628, -1.5656,  1.4894],
#         [ 0.6573, -2.2069,  0.2176,  ...,  0.9581, -0.0551,  1.1557]],
#        requires_grad=True)

# %%
embedding_layer
# Out:
# Embedding(4589, 100)

# %%
# embeddings for closely related words
word1 = 'time'
word2 = 'machine'

#their embeddings
embed1 = embedding_layer.weight.detach()[word2idx[word1],:]
embed2 = embedding_layer.weight.detach()[word2idx[word2],:]

#cosine sim btw them
cosSim = torch.dot(embed1,embed2)/torch.norm(embed1)*torch.norm(embed2)

plt.plot(embed1,embed2,'ks',markerfacecolor=[.7,.9,.7],alpha=.6)
plt.gca().set(xlabel=f'Embedding for "{word1}"', ylabel = f'Embedding for "{word2}"',
              title = f'Cosine sim: {cosSim}')
plt.show()

# %%
# Build the model

class EmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, context_size):
        super(EmbeddingModel, self).__init__()

        # embedding layer
        self.embeddings = nn.Embedding(vocab_size,embedding_dim) #4589x100

        #linear hidden layers
        self.linear1 = nn.Linear(context_size * embedding_dim, 128) #600x128
        self.linear2 = nn.Linear(128, vocab_size) #128*4589

    def forward(self, inputs):
        # the fwd pass process the current token to predict next token
        
        # extract and flatten embeddings, reshapes to [batch_size, context_size * embedding_dim]
        embeds = self.embeddings(inputs).view(inputs.shape[0],-1)
        # print(embeds.shape)
        #fully connected layers
        out = F.relu(self.linear1(embeds)) #connecting to first H.L
        out = self.linear2(out)

        #log softmax for classfcn ( NLLLoss expects logprobs as inputs)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs

# create a model instance
model = EmbeddingModel(vocab_size=nVocab, embedding_dim=embeddingDimension, context_size=context_length)
print(model)



# apply Xavier normlsn on initialise weights, so that Std deviation of weights is tighter
# helps in training
for param in model.parameters():
    if param.dim()>1: #also exlcudes biases
        nn.init.xavier_normal_(param)
# Out:
# EmbeddingModel(
#   (embeddings): Embedding(4589, 100)
#   (linear1): Linear(in_features=600, out_features=128, bias=True)
#   (linear2): Linear(in_features=128, out_features=4589, bias=True)
# )

# %%
#lets test the model

X,y = next(iter(dataloader))
modelOut = model(X)

print('input to model:')
print(X.shape)
print(X), print('')

print(f'Output from model (size: {list(modelOut.detach().shape)}):')
print(modelOut)
# Out:
# input to model:
# torch.Size([32, 6])
# tensor([[2731, 4042,  904, 1885, 4047, 3844],
#         [ 319, 2731,  824, 4041, 4042, 1533],
#         [4544, 4510, 3712, 2731, 4041,  750],
#         [4042, 2576, 2960, 2742,  501, 1297],
#         [ 902, 1832, 4142, 2521, 2268, 1484],
#         [2186, 2186, 2468,  319, 4041, 4042],
#         [3131, 4041, 3560, 1925, 4119,  319],
#         [4341, 4486, 4200, 2031, 2186, 4408],
#         [1647, 1572, 1929, 4414, 4042, 2779],
#         [1659, 4481, 4549, 1553, 2470, 2368],
#         [4510, 2187, 3532, 2731, 1139, 4408],
#         [3392, 4489, 1802, 4466, 2183, 1166],
#         [4408,  104, 2041, 3317, 2608, 1800],
#         [3282, 4119,  464, 4510, 2470, 4119],
#         [2163, 4042, 1659, 2186, 4549, 3831],
#         [1925, 1815, 1824, 2518, 4119, 1553],
#         [  75, 1977, 1522, 2183, 2669,  942],
#         [ 930, 4041, 1815,  339, 3815, 2732],
#         [3388, 2186, 4134, 4230, 4572, 4119],
#         [ 967,  726,  137, 3001, 2767,  137],
#         [ 151, 4065, 4041,  204, 2698, 2494],
#         [2608, 1835, 2732, 4043, 3041, 2282],
#         [ 137, 4352,  960, 2420, 4051, 4408],
#         [3187, 1640, 4043,  917,  349, 4077],
#         [1815, 1453, 3965, 1945, 2731, 4233],
#         [4058, 4454, 3116, 2163, 2608, 2974],
#         [2608, 1492, 2407, 2731,  521, 4400],
#         [1572,  382, 2731, 2477, 1868, 2387],
#         [ 501, 4525, 4114, 4510,  477,    6],
#         [3406, 4042, 2250, 1313,  230,  340],
#         [3793, 3854,  137, 1676, 2041, 4042],
#         [ 519, 2041,  137, 4390,  178, 4516]])
#
# Output from model (size: [32, 4589]):
# tensor([[-8.4190, -8.3506, -8.3609,  ..., -8.4929, -8.4947, -8.4953],
#         [-8.4154, -8.3517, -8.3577,  ..., -8.4947, -8.4937, -8.4937],
#         [-8.4216, -8.3549, -8.3617,  ..., -8.4906, -8.4948, -8.4954],
#         ...,
#         [-8.4127, -8.3551, -8.3581,  ..., -8.4918, -8.4961, -8.4946],
#         [-8.4215, -8.3527, -8.3565,  ..., -8.4943, -8.4946, -8.4976],
#         [-8.4192, -8.3523, -8.3611,  ..., -8.4848, -8.4975, -8.4944]],
#        grad_fn=<LogSoftmaxBackward0>)

# %%
y
# Out:
# tensor([[4042,  904, 1885, 4047, 3844, 2741],
#         [2731,  824, 4041, 4042, 1533, 1019],
#         [4510, 3712, 2731, 4041,  750, 1815],
#         [2576, 2960, 2742,  501, 1297, 2740],
#         [1832, 4142, 2521, 2268, 1484,  519],
#         [2186, 2468,  319, 4041, 4042, 3933],
#         [4041, 3560, 1925, 4119,  319, 2740],
#         [4486, 4200, 2031, 2186, 4408, 1030],
#         [1572, 1929, 4414, 4042, 2779,  230],
#         [4481, 4549, 1553, 2470, 2368, 1091],
#         [2187, 3532, 2731, 1139, 4408,   12],
#         [4489, 1802, 4466, 2183, 1166, 4119],
#         [ 104, 2041, 3317, 2608, 1800,  137],
#         [4119,  464, 4510, 2470, 4119, 2780],
#         [4042, 1659, 2186, 4549, 3831,  319],
#         [1815, 1824, 2518, 4119, 1553, 4108],
#         [1977, 1522, 2183, 2669,  942, 3451],
#         [4041, 1815,  339, 3815, 2732, 1572],
#         [2186, 4134, 4230, 4572, 4119, 2426],
#         [ 726,  137, 3001, 2767,  137, 4042],
#         [4065, 4041,  204, 2698, 2494, 1147],
#         [1835, 2732, 4043, 3041, 2282, 1390],
#         [4352,  960, 2420, 4051, 4408, 2190],
#         [1640, 4043,  917,  349, 4077, 4041],
#         [1453, 3965, 1945, 2731, 4233, 1288],
#         [4454, 3116, 2163, 2608, 2974,  506],
#         [1492, 2407, 2731,  521, 4400,  341],
#         [ 382, 2731, 2477, 1868, 2387,   36],
#         [4525, 4114, 4510,  477,    6, 4042],
#         [4042, 2250, 1313,  230,  340, 1815],
#         [3854,  137, 1676, 2041, 4042,  576],
#         [2041,  137, 4390,  178, 4516, 3462]])

# %%
len(modelOut[0])
# Out:
# 4589

# %%
X[0]
# Out:
# tensor([2731, 4042,  904, 1885, 4047, 3844])

# %%
# the 2X4589 matrix in above output
# each row is the logsoftmax value for every possible word in the vocab to 
# be predicted as the final token in the seq

# %%
# log softmax output:
print(modelOut.detach()[0])
print('')

#shouldnt the sum be 1 ??
print(f'Log softmax sum = {modelOut.detach()[0].sum()}')

#ah its *log* softmax :D
print(f'exp(log(softmax) sum = {torch.exp(modelOut.detach()[0]).sum()}')
# Out:
# tensor([-8.4190, -8.3506, -8.3609,  ..., -8.4929, -8.4947, -8.4953])
#
# Log softmax sum = -38697.71875
# exp(log(softmax) sum = 0.9999990463256836

# %%
# find word with highest prob
print('Model input:')
print([idx2word[w.item()] for w in X[0]])
print('')

print('Model output:')
print(idx2word[modelOut[0].argmax().item()])
# Out:
# Model input:
# ['of', 'the', 'darkling', 'heavens', 'then', 'stopped']
#
# Model output:
# rotted

# %%
# have the model generate text

# grab some data from loader
X,y = next(iter(dataloader))

print('First input:')
print(' '.join([idx2word[w.item()] for w in X[0]]))
print('\nsubsequent inputs:')

# text generation
for _ in range(context_length):
    # get output for this input
    Y = model(X)

    #pick the most liekely next word
    nextWord = Y[0].argmax().item()

    #create new input for next iteration (word)
    X[0] = torch.concatenate((X[0][1:], torch.tensor([nextWord])))

    # print out generated text so far
    print(' '.join([idx2word[w.item()] for w in X[0]]))
# Out:
# First input:
# the future were alike and the
#
# subsequent inputs:
# future were alike and the yesterday
# were alike and the yesterday rotted
# alike and the yesterday rotted rotted
# and the yesterday rotted rotted doing
# the yesterday rotted rotted doing doing
# yesterday rotted rotted doing doing vegetable

# %%
' '.join([idx2word[w.item()] for w in y[0]])
# Out:
# 'future were alike and the children'

# %%
# summary of the model

summary(model,input_data = X, col_names=['input_size', 'output_size','num_params'])
# Out:
# ===================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #
# ===================================================================================================================
# EmbeddingModel                           [32, 6]                   [32, 4589]                --
# ├─Embedding: 1-1                         [32, 6]                   [32, 6, 100]              458,900
# ├─Linear: 1-2                            [32, 600]                 [32, 128]                 76,928
# ├─Linear: 1-3                            [32, 128]                 [32, 4589]                591,981
# ===================================================================================================================
# Total params: 1,127,809
# Trainable params: 1,127,809
# Non-trainable params: 0
# Total mult-adds (M): 36.09
# ===================================================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.36
# Params size (MB): 4.51
# Estimated Total Size (MB): 5.87
# ===================================================================================================================

# %% [markdown]
# ![alt text for screen readers](./code_arch_mapping.png)

# %% [markdown]
# ## Loss function to train the embeddings

# %%
# refer to notebook: embed_LossFunction

# %% [markdown]
# ## Train and evaluate model

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: mps

# %%
# create a fresh instance of model
model = EmbeddingModel(vocab_size=nVocab, embedding_dim=embeddingDimension, context_size=context_length)

# with Xavier weight disbn
for param in model.parameters():
    if param.dim()>1: #also exlcudes biases
        nn.init.xavier_normal_(param)

#move the model to GPU
model = model.to(device)

# %%
# creae loss and optimizer func
loss_function = nn.NLLLoss().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=.001, weight_decay=.01)

# %%
# quick test for errors and sanity check the output matrix sizes
X,y = next(iter(dataloader))
X,y = X.to(device), y.to(device)

# fwd pass
modelOutput = model(X)

# check the sizes
print(f'Model input is of size: {X.shape}') #IRL, we train on 1000s of seq length, here only 6
print(f'Target output is of size: {y.shape}')
print(f'Model output is of size: {modelOutput.shape}') # log softmax prob for all 4500 tokens for 
# each of the final token in the seq

# loss func
loss = loss_function(modelOutput,y[:,-1])  # loss is based on the last token of a sequence
print(f'\nLoss: {loss}')
# Out:
# Model input is of size: torch.Size([32, 6])
# Target output is of size: torch.Size([32, 6])
# Model output is of size: torch.Size([32, 4589])
#
# Loss: 8.431657791137695

# %%
print(modelOutput.shape)
modelOutput
# Out:
# torch.Size([32, 4589])
# tensor([[-8.3605, -8.4868, -8.4552,  ..., -8.3727, -8.4145, -8.3843],
#         [-8.3626, -8.4885, -8.4548,  ..., -8.3738, -8.4193, -8.3839],
#         [-8.3527, -8.4914, -8.4577,  ..., -8.3681, -8.4141, -8.3876],
#         ...,
#         [-8.3610, -8.4865, -8.4589,  ..., -8.3759, -8.4134, -8.3872],
#         [-8.3548, -8.4829, -8.4588,  ..., -8.3816, -8.4199, -8.3821],
#         [-8.3591, -8.4863, -8.4578,  ..., -8.3753, -8.4235, -8.3803]],
#        device='mps:0', grad_fn=<LogSoftmaxBackward0>)

# %%
X
# Out:
# tensor([[2717, 3687, 4510, 4042, 1884, 2731],
#         [4066,  230, 4408, 3463, 3533, 1640],
#         [2957,  137, 3336, 4042,  359, 2041],
#         [4041, 2358, 4053, 4428, 2604,  741],
#         [ 137, 2569, 3457, 1815, 1742, 3820],
#         [4111,  137, 2698, 1815, 2685, 4042],
#         [2569, 4039, 4428,  522, 4042, 3771],
#         [3554, 2069, 1861, 3495, 2470,  230],
#         [2368, 3803, 4230, 2764, 4086, 2572],
#         [2739, 1414, 1719,  557, 2731, 2780],
#         [4042, 2659,  137, 4042,  903, 1965],
#         [3714, 3923, 4041, 4043, 2965, 3554],
#         [ 577,  255, 2275, 3821, 4225,  473],
#         [1599, 2609, 2628, 4042, 2545, 2731],
#         [1815,  339, 4546,  280, 1654, 2041],
#         [1487, 4510, 3531, 2731, 2835, 2041],
#         [1451,  280, 1640, 2470,  137,  519],
#         [1298, 4041, 3554, 2210,  255, 4042],
#         [2608, 1388, 2395, 2669, 4109, 2041],
#         [2186, 2468,  319,  230, 4560,  131],
#         [ 137,   96, 4042, 4148, 2731, 2334],
#         [ 999,    6,  484,  137, 3696,  218],
#         [1030, 4119, 2010, 4408,  255, 1492],
#         [4458, 4523, 4408, 4073, 2312, 1108],
#         [1097, 4466, 4454, 2740, 1929, 1450],
#         [  19,  137, 2187, 3948, 2317, 1297],
#         [2731, 1901, 2230, 4041, 1019, 2685],
#         [ 506, 3215, 4119, 4086, 2952, 1183],
#         [4041, 3141,  137, 1543,  340, 2608],
#         [2041, 4042,  902,  137, 2186, 4408],
#         [2646, 2470, 3162, 4119, 3054, 3549],
#         [1487, 2731, 1769, 4529,  137, 1165]], device='mps:0')

# %%
y
# Out:
# tensor([[3687, 4510, 4042, 1884, 2731, 2187],
#         [ 230, 4408, 3463, 3533, 1640, 4042],
#         [ 137, 3336, 4042,  359, 2041, 2858],
#         [2358, 4053, 4428, 2604,  741, 4408],
#         [2569, 3457, 1815, 1742, 3820, 2740],
#         [ 137, 2698, 1815, 2685, 4042, 1403],
#         [4039, 4428,  522, 4042, 3771, 2731],
#         [2069, 1861, 3495, 2470,  230, 4406],
#         [3803, 4230, 2764, 4086, 2572,  519],
#         [1414, 1719,  557, 2731, 2780, 2812],
#         [2659,  137, 4042,  903, 1965,  340],
#         [3923, 4041, 4043, 2965, 3554,  319],
#         [ 255, 2275, 3821, 4225,  473, 2791],
#         [2609, 2628, 4042, 2545, 2731, 4112],
#         [ 339, 4546,  280, 1654, 2041, 4042],
#         [4510, 3531, 2731, 2835, 2041, 2742],
#         [ 280, 1640, 2470,  137,  519, 4119],
#         [4041, 3554, 2210,  255, 4042, 1998],
#         [1388, 2395, 2669, 4109, 2041, 3791],
#         [2468,  319,  230, 4560,  131, 1353],
#         [  96, 4042, 4148, 2731, 2334, 4041],
#         [   6,  484,  137, 3696,  218,  137],
#         [4119, 2010, 4408,  255, 1492, 2055],
#         [4523, 4408, 4073, 2312, 1108, 2041],
#         [4466, 4454, 2740, 1929, 1450, 1929],
#         [ 137, 2187, 3948, 2317, 1297, 1654],
#         [1901, 2230, 4041, 1019, 2685, 1342],
#         [3215, 4119, 4086, 2952, 1183,  255],
#         [3141,  137, 1543,  340, 2608, 1385],
#         [4042,  902,  137, 2186, 4408, 2744],
#         [2470, 3162, 4119, 3054, 3549, 1901],
#         [2731, 1769, 4529,  137, 1165, 3829]], device='mps:0')

# %%
y[:,-1]
# Out:
# tensor([2187, 4042, 2858, 4408, 2740, 1403, 2731, 4406,  519, 2812,  340,  319,
#         2791, 4112, 4042, 2742, 4119, 1998, 3791, 1353, 4041,  137, 2055, 2041,
#         1929, 1654, 1342,  255, 1385, 2744, 1901, 3829], device='mps:0')

# %%
modelOutput[0]
# Out:
# tensor([-8.3605, -8.4868, -8.4552,  ..., -8.3727, -8.4145, -8.3843],
#        device='mps:0', grad_fn=<SelectBackward0>)

# %%
# Extract the pretrained embedding weights for comparison later
pretrained_embeddings = model.embeddings.weight.detach().cpu()
pretrained_embeddings.shape
# Out:
# torch.Size([4589, 100])

# %% [markdown]
#  ## Now train the model

# %%
def trainTheModel(model, num_epochs=25):
    #init the losses
    total_loss = np.zeros(num_epochs)

    for epoch in range(num_epochs):

        #initialize
        epoch_loss = 0

        # loop over batches in data loader
        for X,y in dataloader:

            # move data to GPU
            X,y = X.to(device), y.to(device)

            # clear previous grads
            model.zero_grad()

            # fwd pass
            log_probs = model(X)

            # calculate losses from final target word
            loss = loss_function(log_probs, y[:,-1])

            #backprop
            loss.backward()
            optimizer.step()

            # sum the per epoch losses
            epoch_loss += loss.item()

        # scale by num of tokens in this dataloader
        total_loss[epoch] = epoch_loss/ len(dataloader.dataset)

        print(f' Finished epoch {epoch+1} with loss {epoch_loss/ len(dataloader.dataset)}')

    return model, total_loss

# %%
# train the model

model, total_loss = trainTheModel(model)
# Out:
#  Finished epoch 1 with loss 0.21657281373558757
#  Finished epoch 2 with loss 0.18801792573747064
#  Finished epoch 3 with loss 0.1758887247423566
#  Finished epoch 4 with loss 0.1647446402332648
#  Finished epoch 5 with loss 0.15379523247547391
#  Finished epoch 6 with loss 0.14222379889426232
#  Finished epoch 7 with loss 0.12991533308781414
#  Finished epoch 8 with loss 0.1159990134214495
#  Finished epoch 9 with loss 0.10017884762193227
#  Finished epoch 10 with loss 0.08249588029473866
#  Finished epoch 11 with loss 0.06338115976348718
#  Finished epoch 12 with loss 0.04354144910856748
#  Finished epoch 13 with loss 0.026081115467645546
#  Finished epoch 14 with loss 0.01378450231731678
#  Finished epoch 15 with loss 0.0068019626940867385
#  Finished epoch 16 with loss 0.0034310410550939595
#  Finished epoch 17 with loss 0.0018757862979153852
#  Finished epoch 18 with loss 0.0011388612177407574
#  Finished epoch 19 with loss 0.0007720684409454682
#  Finished epoch 20 with loss 0.0005750038013205933
#  Finished epoch 21 with loss 0.000420095103449392
#  Finished epoch 22 with loss 0.00038687155716097166
#  Finished epoch 23 with loss 0.00030227693641805343
#  Finished epoch 24 with loss 0.00029798694100682804
#  Finished epoch 25 with loss 0.0002496213399222631

# %%
#plot losses
plt.figure(figsize=(10,3))
plt.plot(total_loss,'ks-', markerfacecolor='w', markersize=8)
plt.gca().set(xlabel='Epoch', ylabel='Loss')
plt.show()

# %%
# get trained weights
postrained_embeddings=model.embeddings.weight.detach().cpu()

# %%
postrained_embeddings.shape
# Out:
# torch.Size([4589, 100])

# %% [markdown]
# ## How the embeddings change

# %%
# Embeddings vector for a random word
#pick a word at random

aRandomWord = np.random.choice(vocab)
randWord_idx = word2idx[aRandomWord]
print(aRandomWord)
# extract its emb vectors
pre_ev = pretrained_embeddings[randWord_idx,:]
post_ev = postrained_embeddings[randWord_idx,:]

_,axs = plt.subplots(2,2,figsize=(10,7))

# pretrainned embb
axs[0,0].imshow(pretrained_embeddings.T, aspect='auto', vmin=-.2,vmax=.2)
axs[0,0].set(ylabel='Embedding dimension', xlabel='Token index',title='Pretrained emb')

# post embb
axs[0,1].imshow(postrained_embeddings.T, aspect='auto', vmin=-.2,vmax=.2)
axs[0,1].set(ylabel='Embedding dimension', xlabel='Token index',title='Posttrained emb')

axs[0,0].axvline(randWord_idx, linestyle='--',color=[.8,.8,.8])
axs[0,1].axvline(randWord_idx, linestyle='--',color=[.8,.8,.8])

#plot its embedding
axs[1,0].plot(pre_ev,'ks-',markerfacecolor=[.7,.9,.7], label='PREtrain')
axs[1,0].plot(post_ev,'ko-',markerfacecolor=[.9,.7,.7], label='POSTtrain')
axs[1,0].set(xlabel='embedding dimension', ylabel='Weigth value', title=f'"{aRandomWord}"')
axs[1,0].legend(fontsize=8)

# how it changed
axlim = max(abs(pre_ev).max(),abs(post_ev).max()) * 1.1 #equal axis limits
axs[1,1].plot(pre_ev,post_ev,'ks',markerfacecolor=[.9,.7,.9])
axs[1,1].set(xlabel='PREtrain embdeding',
             ylabel='POSTtrain embedding',
             title='Change in embedding')

plt.tight_layout()
plt.show()
# Out:
# rags

# %%
# 'TIME' AND 'MACHINE' embeddings
# TIME and MACHINE appear together quite often, so it should have similar embedd
# Appearing together ≠ similar embeddings
# ✔ Embeddings reflect meaning, not adjacency
# because NEW and YORK contexts differ their embedding not similar, even though they appear together.
# ✔ “New” and “York” have very different meanings, so their embeddings differ
# embedding learn relational structure and semantic meaning, not adjacency

# %%
word1 = 'time'
word2 = 'machine'

# their embeddings
embed1pre = pretrained_embeddings[word2idx[word1],:]
embed2pre = pretrained_embeddings[word2idx[word2],:]
embed1pst = postrained_embeddings[word2idx[word1],:]
embed2pst = postrained_embeddings[word2idx[word2],:]

# cosine sim b/w them
cosSim_pre = nn.functional.cosine_similarity(embed1pre.unsqueeze(dim=0), embed2pre.view(1,-1))
cosSim_pst = nn.functional.cosine_similarity(embed1pst.unsqueeze(dim=0), embed2pst.view(1,-1))

print(f"Pretraing cosine sim: {cosSim_pre}")
print(f"Posttraing cosine sim: {cosSim_pst}")
# Out:
# Pretraing cosine sim: tensor([-0.1694])
# Posttraing cosine sim: tensor([0.1886])

# %%
# cosine sim improved

# %%
# cosine manually

num = torch.dot(embed1pst, embed2pst)
den = torch.norm(embed1pst)*torch.norm(embed2pst)
cs_man = num/den

# and via pytorcj
cs_pyt = F.cosine_similarity(embed2pst.unsqueeze(dim=0), embed1pst.view(1,-1))

print(f'Cosine sim from numpy: {cs_man}')
print(f'Cosine sim from torch: {cs_pyt}')
# Out:
# Cosine sim from numpy: 0.18863600492477417
# Cosine sim from torch: tensor([0.1886])

# %%
print(embed2pst.shape)
print(embed2pst.unsqueeze(dim=0).shape)
print(embed2pst.view(1,-1).shape)
# Out:
# torch.Size([100])
# torch.Size([1, 100])
# torch.Size([1, 100])

# %%
embed2pst.unsqueeze(dim=0)
# Out:
# tensor([[-0.1515, -0.1088,  0.0400,  0.0231, -0.1215,  0.0362, -0.0567, -0.1648,
#          -0.2363, -0.0344, -0.0311, -0.0366,  0.0690, -0.0079,  0.1616, -0.1095,
#          -0.0814,  0.0568,  0.0098, -0.0398, -0.0761,  0.0130,  0.0405,  0.0149,
#          -0.1453,  0.1347, -0.0688,  0.2228, -0.0911,  0.1209,  0.0989,  0.0972,
#           0.0234,  0.0664,  0.0205,  0.0791,  0.0384,  0.0550, -0.1484, -0.1739,
#           0.0746,  0.1060,  0.0932, -0.0190, -0.0140, -0.0149, -0.0915, -0.0133,
#          -0.0844, -0.1790, -0.0338,  0.0024, -0.0494, -0.0821,  0.1505,  0.0954,
#           0.0621, -0.0528, -0.1485,  0.1609,  0.0847, -0.1482, -0.1225, -0.0635,
#          -0.1989,  0.1903,  0.0500,  0.1216,  0.0294,  0.0998, -0.0041,  0.0308,
#          -0.1054, -0.0566,  0.0403, -0.0505, -0.1798,  0.0487,  0.1233, -0.0216,
#           0.1947,  0.0052, -0.0861,  0.0293,  0.0341,  0.1715, -0.1198,  0.0500,
#          -0.1867, -0.0890,  0.0124,  0.1456, -0.1238, -0.0578, -0.1202, -0.0071,
#          -0.1697, -0.0921,  0.1246,  0.0679]])

# %%
embed2pst
# Out:
# tensor([-0.1515, -0.1088,  0.0400,  0.0231, -0.1215,  0.0362, -0.0567, -0.1648,
#         -0.2363, -0.0344, -0.0311, -0.0366,  0.0690, -0.0079,  0.1616, -0.1095,
#         -0.0814,  0.0568,  0.0098, -0.0398, -0.0761,  0.0130,  0.0405,  0.0149,
#         -0.1453,  0.1347, -0.0688,  0.2228, -0.0911,  0.1209,  0.0989,  0.0972,
#          0.0234,  0.0664,  0.0205,  0.0791,  0.0384,  0.0550, -0.1484, -0.1739,
#          0.0746,  0.1060,  0.0932, -0.0190, -0.0140, -0.0149, -0.0915, -0.0133,
#         -0.0844, -0.1790, -0.0338,  0.0024, -0.0494, -0.0821,  0.1505,  0.0954,
#          0.0621, -0.0528, -0.1485,  0.1609,  0.0847, -0.1482, -0.1225, -0.0635,
#         -0.1989,  0.1903,  0.0500,  0.1216,  0.0294,  0.0998, -0.0041,  0.0308,
#         -0.1054, -0.0566,  0.0403, -0.0505, -0.1798,  0.0487,  0.1233, -0.0216,
#          0.1947,  0.0052, -0.0861,  0.0293,  0.0341,  0.1715, -0.1198,  0.0500,
#         -0.1867, -0.0890,  0.0124,  0.1456, -0.1238, -0.0578, -0.1202, -0.0071,
#         -0.1697, -0.0921,  0.1246,  0.0679])

# %%
# Out:
# tensor([[ 0.0174,  0.0249,  0.0640,  ...,  0.0843,  0.0378, -0.0601],
#         [-0.1096, -0.0491,  0.1487,  ...,  0.2210,  0.1193, -0.0050],
#         [-0.1106, -0.2508,  0.1747,  ..., -0.1715, -0.0555, -0.1562],
#         ...,
#         [ 0.0920, -0.0052, -0.2184,  ..., -0.0895, -0.1338, -0.0796],
#         [-0.0130,  0.0640,  0.0293,  ...,  0.0295, -0.0501, -0.0775],
#         [ 0.1027, -0.0406,  0.1530,  ...,  0.0735, -0.1948,  0.0583]])

# %% [markdown]
# ## How stable are the embeddings

# %%
a=100

# %%
a=200
def multi(c,d):
    return c+a
multi(3,4)
# Out:
# 203

# %%
multi(3,4)
# Out:
# 103

# %%
x = 10
y = x
x = 20
print(y)
print(x)
# Out:
# 10
# 20

# %%
a = [1,2,3]
b = [1,2,3]

print(id(a))
print(id(b))
# Out:
# 13588013120
# 13606811776

# %%
id(b)
# Out:
# 13656886144

# %%
a='raeez'
b='raeez'
print(id(a))
print(id(b))
# Out:
# 4366099824
# 4366099824

# %%
def add_item(x, collection=None):
    if collection is None:
        collection = []
    collection.append(x)
    return collection

print(add_item(1))  # [1]
print(add_item(2))
# Out:
# [1]
# [2]

# %%
def logger(fn):
    def wrapper():
        print("Calling function...",fn)
        print("here1")
        return fn()
    print("here2")
    return wrapper

@logger
def greet():
    print("Hello")

greet()
# Out:
# here2
# Calling function... <function greet at 0x32ebad630>
# here1
# Hello

# %%
print(type(len)) 
print(type(int))
print(type([1,2,3]))
# Out:
# <class 'builtin_function_or_method'>
# <class 'type'>
# <class 'list'>

# %%
# How stable are the embeddings

# number of repetitions (new models) and epochs
# 10 diff models trained with 16 epochs each

# all models are identical except for the random initialisations of weights

numRepetitions = 10
numEpochs = 16

# initializations
lossesMatrix = np.zeros((numRepetitions, numEpochs))
embeddingMats = []

# loop over repetitions
for repi in range(numRepetitions):
    # create a new model
    model = EmbeddingModel(vocab_size=nVocab, embedding_dim=embeddingDimension, context_size=context_length)
    model = model.to(device)
    # with Xavier weight disbn
    for param in model.parameters():
        if param.dim()>1: #also exlcudes biases
            nn.init.xavier_normal_(param)

    # need to recreate the optimizer b/c it retains gradient/overhead info
    optimizer = torch.optim.AdamW(model.parameters(), lr=.001, weight_decay=.01)

    # train the model
    print(f'** Running repetition {repi+1}/{numRepetitions} **')
    model, total_loss = trainTheModel(model,numEpochs)
    print('\n')

    # get its losses
    lossesMatrix[repi,:] = total_loss

    # extract embedding matrix
    embeddingMats.append(model.embeddings.weight.detach().cpu())
# Out:
# ** Running repetition 1/10 **
#  Finished epoch 1 with loss 0.21702013844421167
#  Finished epoch 2 with loss 0.18795965023374478
#  Finished epoch 3 with loss 0.17572378597235286
#  Finished epoch 4 with loss 0.16560335921793784
#  Finished epoch 5 with loss 0.15507055727131216
#  Finished epoch 6 with loss 0.14313609529457394
#  Finished epoch 7 with loss 0.1299973465622421
#  Finished epoch 8 with loss 0.1153785905557438
#  Finished epoch 9 with loss 0.09910145547893108
#  Finished epoch 10 with loss 0.08114483783862864
#  Finished epoch 11 with loss 0.061762657511351966
#  Finished epoch 12 with loss 0.04223507374172604
#  Finished epoch 13 with loss 0.02534267310988529
#  Finished epoch 14 with loss 0.013717360227248522
#  Finished epoch 15 with loss 0.007002005596982805
#  Finished epoch 16 with loss 0.0035957022631154384
#
#
# ** Running repetition 2/10 **
#  Finished epoch 1 with loss 0.2169841486808084
#  Finished epoch 2 with loss 0.18788712535735486
#  Finished epoch 3 with loss 0.17533970559613934
#  Finished epoch 4 with loss 0.16489496325225428
#  Finished epoch 5 with loss 0.15511090176835599
#  Finished epoch 6 with loss 0.14414298673049408
#  Finished epoch 7 with loss 0.1320515710370024
#  Finished epoch 8 with loss 0.1185196513316811
#  Finished epoch 9 with loss 0.10288380553512416
#  Finished epoch 10 with loss 0.08577208079244021
#  Finished epoch 11 with loss 0.06708067526228674
#  Finished epoch 12 with loss 0.04772081002032299
#  Finished epoch 13 with loss 0.029809436765121187
#  Finished epoch 14 with loss 0.016533032860728887
#  Finished epoch 15 with loss 0.0087195416793552
#  Finished epoch 16 with loss 0.004546640548782607
#
#
# ** Running repetition 3/10 **
#  Finished epoch 1 with loss 0.21736101791453424
#  Finished epoch 2 with loss 0.18786521783358376
#  Finished epoch 3 with loss 0.1741763172628779
#  Finished epoch 4 with loss 0.16314066387367043
#  Finished epoch 5 with loss 0.15314558598433825
#  Finished epoch 6 with loss 0.14248908723091616
#  Finished epoch 7 with loss 0.13063496304052385
#  Finished epoch 8 with loss 0.11715708754417099
#  Finished epoch 9 with loss 0.10214545714891314
#  Finished epoch 10 with loss 0.08552663046154804
#  Finished epoch 11 with loss 0.06708584802612835
#  Finished epoch 12 with loss 0.047715101572043644
#  Finished epoch 13 with loss 0.02983218438172548
#  Finished epoch 14 with loss 0.016532893043822317
#  Finished epoch 15 with loss 0.008643090982740546
#  Finished epoch 16 with loss 0.004489028156561045
#
#
# ** Running repetition 4/10 **
#  Finished epoch 1 with loss 0.2166958200583161
#  Finished epoch 2 with loss 0.18747422902794508
#  Finished epoch 3 with loss 0.17464432713107134
#  Finished epoch 4 with loss 0.1643064181693499
#  Finished epoch 5 with loss 0.15438224768058353
#  Finished epoch 6 with loss 0.14357337894799505
#  Finished epoch 7 with loss 0.13146171571222431
#  Finished epoch 8 with loss 0.11800634622131086
#  Finished epoch 9 with loss 0.10256728383991658
#  Finished epoch 10 with loss 0.08525081086794939
#  Finished epoch 11 with loss 0.06615219998483189
#  Finished epoch 12 with loss 0.04626250167988738
#  Finished epoch 13 with loss 0.028553371254783282
#  Finished epoch 14 with loss 0.015854629474864913
#  Finished epoch 15 with loss 0.008384762997997085
#  Finished epoch 16 with loss 0.004289013243772548
#
#
# ** Running repetition 5/10 **
#  Finished epoch 1 with loss 0.21721221671031257
#  Finished epoch 2 with loss 0.18810165766198758
#  Finished epoch 3 with loss 0.17571771982629422
#  Finished epoch 4 with loss 0.16521754314701131
#  Finished epoch 5 with loss 0.1548498205140753
#  Finished epoch 6 with loss 0.14371284251454963
#  Finished epoch 7 with loss 0.13149987797200674
#  Finished epoch 8 with loss 0.11771717876437682
#  Finished epoch 9 with loss 0.10182759113039583
#  Finished epoch 10 with loss 0.0842822595095194
#  Finished epoch 11 with loss 0.06530046326686952
#  Finished epoch 12 with loss 0.04584067822807684
#  Finished epoch 13 with loss 0.02860860749547543
#  Finished epoch 14 with loss 0.01575305402226467
#  Finished epoch 15 with loss 0.008090643762563427
#  Finished epoch 16 with loss 0.004118626894122192
#
#
# ** Running repetition 6/10 **
#  Finished epoch 1 with loss 0.21726710448434258
#  Finished epoch 2 with loss 0.1878580221646506
#  Finished epoch 3 with loss 0.17516158587444844
#  Finished epoch 4 with loss 0.16397067554627867
#  Finished epoch 5 with loss 0.15300774038298226
#  Finished epoch 6 with loss 0.14145110094142954
#  Finished epoch 7 with loss 0.1288042847985059
#  Finished epoch 8 with loss 0.11450269469044073
#  Finished epoch 9 with loss 0.09818610340115053
#  Finished epoch 10 with loss 0.07948532254567024
#  Finished epoch 11 with loss 0.05909288788270582
#  Finished epoch 12 with loss 0.03875139590734005
#  Finished epoch 13 with loss 0.02194840572362957
#  Finished epoch 14 with loss 0.011306861782718317
#  Finished epoch 15 with loss 0.0056566728723036344
#  Finished epoch 16 with loss 0.0029820812322281635
#
#
# ** Running repetition 7/10 **
#  Finished epoch 1 with loss 0.21634905909923338
#  Finished epoch 2 with loss 0.18759386011167842
#  Finished epoch 3 with loss 0.1748334576384248
#  Finished epoch 4 with loss 0.1641027595789222
#  Finished epoch 5 with loss 0.15398861678881026
#  Finished epoch 6 with loss 0.14290276133947716
#  Finished epoch 7 with loss 0.13071883548542315
#  Finished epoch 8 with loss 0.11690478114692152
#  Finished epoch 9 with loss 0.10132575270461029
#  Finished epoch 10 with loss 0.08367126786852148
#  Finished epoch 11 with loss 0.0645517825427823
#  Finished epoch 12 with loss 0.04490781419963014
#  Finished epoch 13 with loss 0.027641294534086844
#  Finished epoch 14 with loss 0.015078559267347294
#  Finished epoch 15 with loss 0.007698066670248416
#  Finished epoch 16 with loss 0.003861651130405855
#
#
# ** Running repetition 8/10 **
#  Finished epoch 1 with loss 0.21712283120571535
#  Finished epoch 2 with loss 0.18774619147686908
#  Finished epoch 3 with loss 0.17463668398744794
#  Finished epoch 4 with loss 0.16335329940948023
#  Finished epoch 5 with loss 0.15296732229334017
#  Finished epoch 6 with loss 0.14185195283309046
#  Finished epoch 7 with loss 0.1293706336500078
#  Finished epoch 8 with loss 0.11542176780853555
#  Finished epoch 9 with loss 0.09927514062903282
#  Finished epoch 10 with loss 0.08101204530827613
#  Finished epoch 11 with loss 0.06117540410322104
#  Finished epoch 12 with loss 0.041185927593793095
#  Finished epoch 13 with loss 0.024097174312837453
#  Finished epoch 14 with loss 0.012506719337461888
#  Finished epoch 15 with loss 0.006288981028924344
#  Finished epoch 16 with loss 0.003219528347486835
#
#
# ** Running repetition 9/10 **
#  Finished epoch 1 with loss 0.21691349726969542
#  Finished epoch 2 with loss 0.18818558156111642
#  Finished epoch 3 with loss 0.17557794347954522
#  Finished epoch 4 with loss 0.16490205139862618
#  Finished epoch 5 with loss 0.1545125318405484
#  Finished epoch 6 with loss 0.14317504856992172
#  Finished epoch 7 with loss 0.1311570409805168
#  Finished epoch 8 with loss 0.11787084435079002
#  Finished epoch 9 with loss 0.10296452137489681
#  Finished epoch 10 with loss 0.08647590234195507
#  Finished epoch 11 with loss 0.06839632265566148
#  Finished epoch 12 with loss 0.049596895588748136
#  Finished epoch 13 with loss 0.031871930724562424
#  Finished epoch 14 with loss 0.01811905012267296
#  Finished epoch 15 with loss 0.009529135634083282
#  Finished epoch 16 with loss 0.004934932781683246
#
#
# ** Running repetition 10/10 **
#  Finished epoch 1 with loss 0.21698661261133384
#  Finished epoch 2 with loss 0.18745831284585
#  Finished epoch 3 with loss 0.17434191291323622
#  Finished epoch 4 with loss 0.16352430250786604
#  Finished epoch 5 with loss 0.1534118282050404
#  Finished epoch 6 with loss 0.14273248945975767
#  Finished epoch 7 with loss 0.13069889638887894
#  Finished epoch 8 with loss 0.11692277502657067
#  Finished epoch 9 with loss 0.10129281701073131
#  Finished epoch 10 with loss 0.08407587480037026
#  Finished epoch 11 with loss 0.06538973140315732
#  Finished epoch 12 with loss 0.04599549932664423
#  Finished epoch 13 with loss 0.028832094883851182
#  Finished epoch 14 with loss 0.01619918856781816
#  Finished epoch 15 with loss 0.008633574343618439
#  Finished epoch 16 with loss 0.004653599597320693

# %%
# plot the losses
plt.figure(figsize=(10,4))

#in a for loop to get diff colors
for i in range(numRepetitions):
    plt.plot(lossesMatrix[i,:],'s-',linewidth=2,color=mpl.cm.plasma(i/numRepetitions))

plt.legend()
plt.gca().set(xticks=range(numEpochs),xlabel='Training epohs',ylabel='Losses')
plt.show()
# Out:
# /var/folders/kp/vjs9jtxn58jc4yz25r1fmfqw0000gn/T/ipykernel_33539/459557679.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# so loss is same across diff runs

# will the mebeddings be same as well?


# i.e is the  vectors consistent in terms of their direcntion in embed space
# across diff runs?????

# %%
# consistency of embedd vectors
_,axs = plt.subplots(3,2,figsize=(14,8))

# random words
randWords = np.random.choice(vocab, size=np.prod(axs.shape))

# initialize tensors for all selected vectors
selectedVectors = torch.zeros((len(randWords),numRepetitions, embeddingDimension))

#whayt do individual embedd look like
for wordi,ax in enumerate(axs.flatten()):
    #index of random word
    randWord_idx = word2idx[randWords[wordi]]

    # loop over reps
    for repi in range(numRepetitions):
        #draw lines for embedd in each rep
        ax.plot(embeddingMats[repi][randWord_idx,:])

        #get emebedding vecrtor for this word and repetition
        selectedVectors[wordi,repi,:] = embeddingMats[repi][randWord_idx,:]

    #title of this subplot
    ax.set_title(f'"{randWords[wordi]}" embedding ', fontsize=14)


# final adjustments
for a in axs.flatten():
    a.set(xticks=[],yticks=[],xlim=[-1,embeddingDimension])
ax.set(xlabel='Embedidng dimension',ylabel='Weight value')
plt.tight_layout()
plt.show()

# %%
# the graph shows that the vectors have no consistency across runs

# %%
# above we explored if vectors for a token is stable across model inits

# now lets look at the relation b/w pairs of vectors (cosine sim)


# pick 3 words
word1 ='time'
word2 = 'machine'
word3 = 'she'

#vector of cosine sim for each rep
cossim = np.zeros((numRepetitions,3))

for repi in range(numRepetitions):

    # their emebdd
    e1 = embeddingMats[repi][word2idx[word1],:]
    e2 = embeddingMats[repi][word2idx[word2],:]
    e3 = embeddingMats[repi][word2idx[word3],:]

    # cosine sim b./w each pair
    cossim[repi,0] = nn.functional.cosine_similarity(e1,e2.view(1,-1)).item()
    cossim[repi,1] = nn.functional.cosine_similarity(e1,e3.view(1,-1)).item()
    cossim[repi,2] = nn.functional.cosine_similarity(e2,e3.view(1,-1)).item()

plt.figure(figsize=(10,4))
plt.plot(cossim[:,0],'ks', markerfacecolor=[.9,.7,.7],markersize=12,label=f'"{word1}" vs "{word2}"')
plt.plot(cossim[:,1],'ko', markerfacecolor=[.7,.8,.7],markersize=12,label=f'"{word1}" vs "{word3}"')
plt.plot(cossim[:,2],'k^', markerfacecolor=[.7,.7,.8],markersize=12,label=f'"{word2}" vs "{word3}"')

plt.axhline(0,color=[.7,.7,.7],linestyle='--',zorder=-10)
plt.gca().set(xticks=range(numRepetitions),ylim=[-.4,.6],
              xlabel='Training repetition',
              ylabel='Cosine Similariyt',
              title='Cosine similarities')
plt.legend()
plt.show()
