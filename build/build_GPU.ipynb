# %%
# this shows the use and transfer of data and models across CPU and GPU

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import time

# %%
# On Apple Silicon Macs (M1 / M2 / M4 Pro), GPU = MPS (Metal Performance Shaders), not CUDA.

#checking if GPU available , (both should be True)
print(torch.backends.mps.is_available()) 
print(torch.backends.mps.is_built())
# Out:
# True
# True

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %% [markdown]
# Build a simple model

# %%
# this model is constructed on CPU
net = nn.Sequential(
    nn.Linear(20,100),
    nn.ReLU(),
    nn.Linear(100,500),
    nn.ReLU(),
    nn.Linear(500,30),
    nn.ReLU(),
    nn.Linear(30,2)
)
print(next(net.parameters()).device)
# Out:
# cpu

# %%
# make some data
#data also on CPU
data  = torch.randn(1000,20) # samples X features
labels = torch.randint(low=0, high=2, size=(1,1000))
print(data.device)
# Out:
# cpu

# %%
# send the model and data to GPU
net.to(device)

# data = data.to(device) #data could also be send in place as well
data = data.to(device)
labels = labels.to(device)

# %%
print(next(net.parameters()).device)
print(data.device)
print(labels.device)
# Out:
# mps:0
# mps:0
# mps:0

# %%
data # note the device = 'mps:0'
# Out:
# tensor([[ 1.6820,  1.4782, -1.9745,  ..., -0.7563, -0.6539, -0.4978],
#         [-2.3056, -1.5961, -0.3067,  ..., -0.1395,  0.6848,  1.5434],
#         [-0.8810, -0.6352,  0.3070,  ...,  0.6272, -1.7864,  0.6587],
#         ...,
#         [-0.1393, -0.6178,  0.7714,  ..., -0.5566,  0.4932, -0.7050],
#         [ 0.2533, -0.4236,  0.1474,  ..., -0.3841, -0.5746, -1.5299],
#         [ 0.7490, -0.2993, -0.5315,  ..., -1.9279, -1.6765, -0.4460]],
#        device='mps:0')

# %% [markdown]
# NOTE:
#
#     .to() is only available for Pytorch variables, not a generic Python function

# %%
# you can also create data directly on GPU
dataG = torch.randn((1000,20),device =device)
dataC = torch.randn((1000,20),device ='cpu')

print(data.device)
print(dataG.device)
print(dataC.device)
# Out:
# mps:0
# mps:0
# cpu

# %% [markdown]
# Geting results from model

# %%
output  =  net(dataC)
#this throw error as data in CPU, but model in GPU
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 output  =  net(dataC)
#       2 #this throw error as data in CPU, but model in GPU
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: Tensor for argument input is on cpu but expected on mps

# %%
output = net(data)

# %%
output.device # output is now in GPU
# Out:
# device(type='mps', index=0)

# %%
# try to plot the data
plt.plot(output.detach())
# as output is still in GPU, this throw error
# we need to push back output to CPU and then visualize
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # try to plot the data
# ----> 2 plt.plot(output.detach())
#       3 # as output is still in GPU, this throw error
#       4 # we need to push back output to CPU and then visualize
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)
#    3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/axes/_base.py:486, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     484     y = _check_1d(xy[1])
#     485 else:
# --> 486     x, y = index_of(xy[-1])
#     488 if axes.xaxis is not None:
#     489     axes.xaxis.update_units(x)
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/cbook.py:1676, in index_of(y)
#    1674     pass
#    1675 try:
# -> 1676     y = _check_1d(y)
#    1677 except (VisibleDeprecationWarning, ValueError):
#    1678     # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#    1679     pass
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/cbook.py:1361, in _check_1d(x)
#    1359 """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1360 # Unpack in case of e.g. Pandas or xarray object
# -> 1361 x = _unpack_to_numpy(x)
#    1362 # plot requires `shape` and `ndim`.  If passed an
#    1363 # object that doesn't provide them, then force to numpy array.
#    1364 # Note this will strip unit information.
#    1365 if (not hasattr(x, 'shape') or
#    1366         not hasattr(x, 'ndim') or
#    1367         len(x.shape) < 1):
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/matplotlib/cbook.py:2371, in _unpack_to_numpy(x)
#    2365         return xtmp
#    2366 if _is_torch_array(x) or _is_jax_array(x) or _is_tensorflow_array(x):
#    2367     # using np.asarray() instead of explicitly __array__(), as the latter is
#    2368     # only _one_ of many methods, and it's the last resort, see also
#    2369     # https://numpy.org/devdocs/user/basics.interoperability.html#using-arbitrary-objects-in-numpy
#    2370     # therefore, let arrays do better if they can
# -> 2371     xtmp = np.asarray(x)
#    2373     # In case np.asarray method does not return a numpy array in future
#    2374     if isinstance(xtmp, np.ndarray):
#
# File ~/.pyenv/versions/jupyter-env/lib/python3.10/site-packages/torch/_tensor.py:1226, in Tensor.__array__(self, dtype)
#    1224     return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#    1225 if dtype is None:
# -> 1226     return self.numpy()
#    1227 else:
#    1228     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert mps:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
plt.plot(output.detach().cpu())
#if the pytorch variable has just 1 no, you can use variable.item() isntead of variable.detach().cpu()
# Out:
# [<matplotlib.lines.Line2D at 0x3353149d0>,
#  <matplotlib.lines.Line2D at 0x335314850>]

# %%
output.detach()
# Out:
# tensor([[0.1153, 0.1583],
#         [0.0812, 0.1413],
#         [0.1022, 0.1744],
#         ...,
#         [0.1287, 0.1445],
#         [0.1349, 0.1469],
#         [0.1304, 0.1407]], device='mps:0')
